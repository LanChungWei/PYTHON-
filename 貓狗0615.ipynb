# %%
! pip install tflearn

# %%
! pip install tqdm

# %%
! pip install tensorflow==1.14
# Out:
# ...
#      ---------------------------------------- 68.3/68.3 MB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.1/3.1 MB 5.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 488.5/488.5 kB 7.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 50.7/50.7 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 42.6/42.6 kB ? eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# ...

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl (38.8 MB)
# ...

# %%
# !pip install tensorflow==2.3.0
# Out:
# ...
#      -------------------------------------- 342.5/342.5 MB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 30.9/30.9 MB 4.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 12.7/12.7 MB 4.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 459.0/459.0 kB 4.1 MB/s eta 0:00:00
# ...
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 1.14.0
#     Uninstalling tensorflow-estimator-1.14.0:
#       Successfully uninstalled tensorflow-estimator-1.14.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# ...

# %%
# !pip install --upgrade tensorflow
# Out:
# ...
#   Using cached tensorflow-2.11.0-cp37-cp37m-win_amd64.whl (1.9 kB)
# ...
#   Using cached numpy-1.21.6-cp37-cp37m-win_amd64.whl (14.0 MB)
# ...
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# ...
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
# ...

# %%
import os
import cv2
import numpy as np
from random import shuffle
from tqdm import tqdm

# 使用其中一種方法修正路徑
TRAIN_DIR = r'C:\Users\Aran\Desktop\貓狗\train'
# 或者使用雙反斜杠
# TRAIN_DIR = 'C:\\Users\\Aran\\Desktop\\貓狗\\train'
# 或者使用正斜杠
# TRAIN_DIR = 'C:/Users/Aran/Desktop/貓狗/train'

IMG_SIZE = 50

def label_img(img):
    # 根據你的需求定義標籤
    return [1, 0] if 'cat' in img else [0, 1]

def create_train_data():
    training_data = []
    for img in tqdm(os.listdir(TRAIN_DIR)):
        label = label_img(img)
        path = os.path.join(TRAIN_DIR, img)
        img_data = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if img_data is None:
            print(f"Error loading image: {path}")
            continue
        try:
            img_data = cv2.resize(img_data, (IMG_SIZE, IMG_SIZE))
        except Exception as e:
            print(f"Error resizing image: {path} - {e}")
            continue
        training_data.append([np.array(img_data), np.array(label)])
    shuffle(training_data)
    return training_data

train_data = create_train_data()
# Out:
#  80%|████████  | 9590/11941 [00:00<00:00, 47737.39it/s]
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.0.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.10.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.100.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1000.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1001.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1002.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1003.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1004.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1005.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1006.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1007.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1008.jpg
# Error loading image: C:\Users\Aran\Desktop\貓狗\train\cat.1009.jpg
# ...

# %%
TRAIN_DIR = r'C:\Users\Aran\Desktop\貓狗\train'
TEST_DIR = r'C:\Users\Aran\Desktop\貓狗\test'
IMG_SIZE = 50
LR = 1e-3

MODEL_NAME = 'dogs-vs-cats-convnet'

def label_img(img):
    word_label = img.split('.')[-3]
    if word_label == 'cat': return [1, 0]
    elif word_label == 'dog': return [0, 1]

# %%
def create_train_data():
    training_data = []
    for img in tqdm(os.listdir(TRAIN_DIR)):
        label = label_img(img)
        path = os.path.join(TRAIN_DIR, img)
        img = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (IMG_SIZE, IMG_SIZE))
        training_data.append([np.array(img), np.array(label)])
    shuffle(training_data)
    np.save('train_data.npy', training_data)
    return training_data

# %%
def create_test_data():
    testing_data = []
    for img in tqdm(os.listdir(TEST_DIR)):
        path = os.path.join(TEST_DIR, img)
        img_num = img.split('.')[0]
        img = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (IMG_SIZE, IMG_SIZE))
        testing_data.append([np.array(img), img_num])
    shuffle(testing_data)
    np.save('test_data.npy', testing_data)
    return testing_data

# %%
train_data = create_train_data()
test_data = create_test_data()
# Out:
#   0%|          | 0/11941 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8488\1237093748.py in <module>
# ----> 1 train_data = create_train_data()
#       2 test_data = create_test_data()
#
# ~\AppData\Local\Temp\ipykernel_8488\4053152558.py in create_train_data()
#       4         label = label_img(img)
#       5         path = os.path.join(TRAIN_DIR, img)
# ----> 6         img = cv2.resize(cv2.imread(path, cv2.IMREAD_GRAYSCALE), (IMG_SIZE, IMG_SIZE))
#       7         training_data.append([np.array(img), np.array(label)])
#       8     shuffle(training_data)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
conda create -n tensorflow_env python=3.7
conda activate tensorflow_env
# Out:
#   File "C:\Users\Aran\AppData\Local\Temp\ipykernel_16104\1642884996.py", line 1
#     conda create -n tensorflow_env python=3.7
#                ^
# SyntaxError: invalid syntax
