# %%
import numpy as np
import cv2

face_cascade = cv2.CascadeClassifier(r"C:\Users\Aran\Downloads\haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(r"C:\Users\Aran\Downloads\haarcascade_eye.xml")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import sys, cv2
imagePath = ('C:/Users/Aran/Downloads/1.jfif')
image = cv2.imread(imagePath)

print(image.shape)



plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (234, 417, 3)

# %%
import cv2


face_cascade = cv2.CascadeClassifier(r'C:\Users\Aran\Downloads\haarcascade_frontalface_default.xml')


image = cv2.imread(r'C:\Users\Aran\Downloads\1.jfif')


if image is None:
    print("無法讀取圖片，請檢查圖片路徑！")
else:
 
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv2.CASCADE_SCALE_IMAGE
    )

    print("檢測到的臉部座標:", faces)


    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 2)

    
    cv2.imshow('Detected Faces', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import random
font = cv2.FONT_HERSHEY_SIMPLEX

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (14, 201, 255), 2)
    cv2.putText(image, str(random.randrange(30, 40)), (x + (w // 2) - 18, y - 10), font, 1, (14, 201, 255), 2)
    cv2.rectangle(image, (image.shape[1] - 140, image.shape[0] - 20), (image.shape[1], image.shape[0]), (0, 255, 255), -1)
    cv2.putText(image, "Finding " + str(len(faces)) + " face ", (image.shape[1] - 135, image.shape[0] - 5), cv2.FONT_HERSHEY_TRIPLEX, 0.5, (255, 0, 0), 1)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
num = 1

for (x, y, w, h) in faces:
    filename = "face" + str(num) + ".jpg"
    image = Image.open("beatles.jpg")
    imageCrop = image.crop((x, y, x + w, y + h))
    imageResize = imageCrop.resize((150, 150), Image.ANTIALIAS)  # 高品質: ANTIALIAS
    imageResize.save(filename)
    num += 1

# %%
face2 = cv2.imread('"C:\Users\Aran\Downloads\OIP (2).jfif"')
plt.imshow(cv2.cvtColor(face2, cv2.COLOR_BGR2RGB))
