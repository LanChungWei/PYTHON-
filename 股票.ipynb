# %%
! pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/315.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/315.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/315.3 kB ? eta -:--:--
#      ---- -------------------------------- 41.0/315.3 kB 281.8 kB/s eta 0:00:01
#      --------- --------------------------- 81.9/315.3 kB 508.4 kB/s eta 0:00:01
#      -------------- --------------------- 122.9/315.3 kB 554.9 kB/s eta 0:00:01
#      ------------------ ----------------- 163.8/315.3 kB 614.4 kB/s eta 0:00:01
#      ----------------------------- ------ 256.0/315.3 kB 785.2 kB/s eta 0:00:01
#      -------------------------------- --- 286.7/315.3 kB 842.9 kB/s eta 0:00:01
#      -----------------------------------  307.2/315.3 kB 703.7 kB/s eta 0:00:01
#      ------------------------------------ 315.3/315.3 kB 673.3 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
start_date='1990-01-01'
end_date='2021-07-07'

# %%
ticker='AMZN'
data=yf.download(ticker,start_date,end_date)
data.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-06-29  171.940994  172.801498  171.151505  172.406998  172.406998
# 2021-06-30  172.052994  173.580002  171.750000  172.007996  172.007996
# 2021-07-01  171.730499  172.850006  170.470993  171.648499  171.648499
# 2021-07-02  172.582001  175.585999  171.845993  175.548996  175.548996
# 2021-07-06  176.505493  184.274002  176.449997  183.787003  183.787003
#
#                Volume
# Date
# 2021-06-29   41968000
# 2021-06-30   48080000
# 2021-07-01   40742000
# 2021-07-02   63388000
# 2021-07-06  134896000

# %%
import yfinance as yf
import pandas as pd

# %%
# start_date='1990-01-01'
# end_date='2023-03-03'

# %%
ticker='AMZM'
#data=yf.download(ticker,period = , interval = )
# 股票代號
# period=日期範圍(1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,20y,ytd)
# interval=頻率(1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo)

# %%
data=yf.download(ticker,period='10y',interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf

ticker = "AMZN"  # 這裡可以換成你感興趣的股票代碼
data = yf.download(ticker, period='10y', interval='1d')

print(data.head())  # 打印出數據的前五行以檢視
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Open       High        Low    Close  Adj Close     Volume
# Date
# 2014-04-23  16.6530  16.656500  16.169500  16.2290    16.2290   72092000
# 2014-04-24  16.4835  16.870001  16.147499  16.8575    16.8575  185874000
# 2014-04-25  15.8125  15.824500  15.135500  15.1915    15.1915  323604000
# 2014-04-28  15.2000  15.219500  14.400000  14.8290    14.8290  289596000
# 2014-04-29  14.8220  15.092000  14.522500  15.0190    15.0190  130186000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import yfinance as yf

ticker = "AMZN" 
data = yf.download(ticker, period='10y', interval='1d')

data['Adj Close'].plot(figsize=(10,7))  
plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)  
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14) 
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)  
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import yfinance as yf
import pandas as pd

# %%
tickers_list=['2330.TW','2382.TW','2356.TW']

# %%
data=pd.DataFrame(columns=tickers_list)

# %%
for ticker in tickers_list:
     data[ticker] = yf.download(ticker, period='10y', interval='1d')['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#               2330.TW    2382.TW    2356.TW
# Date
# 2014-04-23  89.566360  43.486618  15.626450
# 2014-04-24  89.566360  43.166473  15.434209
# 2014-04-25  87.715828  41.619095  14.939876
# 2014-04-28  88.085930  42.899681  15.214506
# 2014-04-29  89.196259  43.219822  15.544063

# %%
data.plot(figsize=(10,7))
plt.legend()
plt.title("Adjusted Close Price",fontsize=16)
plt.ylabel('Price',fontsize=14)
plt.xlabel('Year',fontsize=14)
plt.grid(which="major",color='k',linestyle='-.',linewidth=0.5)
plt.show()
