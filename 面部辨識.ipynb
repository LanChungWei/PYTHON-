# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import cv2

face_cascade = cv2.CascadeClassifier(r"C:\Users\Aran\Downloads\haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(r"C:\Users\Aran\Downloads\haarcascade_eye.xml")
img = cv2.imread(r"C:\Users\Aran\Downloads\OIP.jfif")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))

# %%
import cv2
import random

font=cv2.FONT_HERSHEY_SIMPLEX
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    cv2.putText(img, str(random.randrange(20,30)), (x+(w//2)-18, y-10), font, 1, (14, 201, 255), 2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import sys, cv2
imagePath = ('C:/Users/Aran/Downloads/1.jfif')
image = cv2.imread(imagePath)

print(image.shape)

# 顯示原始的 BGR 圖像
plt.imshow(image)
plt.show()

# 將 BGR 圖像轉換為 RGB 圖像並顯示
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (234, 417, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys, cv2
imagePath = ('C:\Users\Aran\Downloads\1.jfif')
image = cv2.imread(imagePath)

# %%
print(image.shape)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('C:\Users\Aran\Downloads\下載.jfif')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30,30),
    flags = cv2.CASCADE_SCALE_IMAGE)
print (faces)

# %%
import random
font=cv2.FONT_HERSHEY_SIMPLEX

for (x, y, w, h) in faces:
    cv2.rectangle(img,(x, y),(x+w, y+h),(144, 201, 255), 2)
    cv2.putText(image, str(random.randrange(30,40)), (x+(w//2)-18, y-10), font, 1, (14, 201, 255), 2)
    cv2.rectangle(image, (image.shape[1]-140, image.shape[0]-20),
                 (image.shape[1], image.shape[0]), (0,255,255), -1)
    cv2.putText(image, "Finding  " + str(len(faces)) + " face ",
               (image.shape[1]-135, image.shape[0]-5),cv2.FONT_HERSHEY_TRIPLEX, 0.5, (255,0,0), 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
num = 1
for (x, y, w, h) in faces:
    filename = "face" + str(num) + ".jpg"
    face_crop = image[y:y+h, x:x+w]  # 裁剪人臉區域
    if not face_crop.size == 0:  # 檢查人臉區域是否為空
        face_resize = cv2.resize(face_crop, (150, 150), interpolation=cv2.INTER_LINEAR)  # 調整大小
        cv2.imwrite(filename, face_resize)  # 保存圖像
        num += 1

# %%
face1=cv2.imread('C:\Users\Aran\Downloads\OIP (2).jfif')

plt.imshow(cv2.cvtColor(face1, cv2.COLOR_BGR2RGB))
# Out:
#   Cell In[13], line 1
#     face1=cv2.imread('C:\Users\Aran\Downloads\OIP (2).jfif')
#                                                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
